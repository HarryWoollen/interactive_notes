# %%
import numpy as np
import matplotlib.pyplot as plt
from generate_data.simple_linear_regression_data import (generate_data,
fit_simple_linear_model,
plot_line_of_best_fit,
plot_residuals)

# %matplotlib inline

# %% [markdown]
# ## Simple Linear Model
#
# Using the notes in `linear_modelling.md` part 1.3.
#
# Derive estimates for $\beta_0$, and $\beta_1$ thus derive a line of best fit $\hat{y}$
#
# Note: You need not derive from first principles, and can use the solved formulas as given.

# %%
#Your output should look like the following
X,Y = generate_data(n=100,type=1)
y_hat_func = fit_simple_linear_model(X,Y)
plot_line_of_best_fit(X,Y,y_hat_func)

# %% [markdown]
# ## Derive $\hat{y}$

# %%
X,Y = generate_data(n=100,type=1)

# Derive beta_1


# Derive beta_0


# Calculate y_hat


#Plot y_hat onto x,y

# %% [markdown]
# ## Investigate Residuals
#
# Now that you have your line of best fit $\hat{y}$
#
# Plot the residuals in different forms as shown below.

# %%
plot_residuals(X,Y,y_hat_func)

# %%
# Plot Residuals



# Plot Standardised Residuals



# Plot Histogram of Standardised Residuals



# Plot Q-Q plot of Standardised Residuals

# %% [markdown]
# Think about what we're looking for in each plot

# %% [markdown]
# ## Example 2.

# %%
X_2,Y_2 = generate_data(n=100,type=2)
y_hat_func_2 = fit_simple_linear_model(X_2,Y_2)
plot_line_of_best_fit(X_2,Y_2,y_hat_func_2)

# %% [markdown]
# ### Derive $\hat{y}$
#
# Theres something a bit different about this plot.
#
# Regardless, find $\hat{y}$ and investigate the residuals
#
# What do these residuals suggest?

# %% [markdown]
# ## Example 3.

# %%
X_3,Y_3 = generate_data(n=50,type=3)
plt.scatter(X_3,Y_3)

# %% [markdown]
# Can you derive a 'sensible' estimate for y. Whilst keeping the model linear
